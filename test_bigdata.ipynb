# %% [markdown]
# <a href="https://colab.research.google.com/github/yeonhas/yeonhas/blob/main/test_bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import os

print("before: %s"%os.getcwd())
os.chdir("/content/gdrive/My Drive/소방청 데이터/")
print("after: %s"%os.getcwd())
# Out:
# before: /content
# after: /content/gdrive/My Drive/소방청 데이터

# %%
import pandas as pd

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' #설치된 나눔글꼴 전체경로
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
# Out:
# NanumGothic

# %%
fm._rebuild()

# %%
df = pd.read_csv('특수건물 자연재해 위험도 지수.csv')

# %%
df.head() #데이터 일부 출력
# Out:
#    SEQ_NO  APLY_YEAR  F_BI_WIND  C  dpjgi_YEAR  dnum_csang_max  dnum_cHA_max  \
# 0       1       2020       1.16  0        1987               3             1
# 1       2       2020       1.37  0        2009               3             1
# 2       3       2020       1.18  0        2002               2             1
# 3       4       2020       1.23  0        1994               3             1
# 4       5       2020       1.30  0        1997               5             1
#
#      YMJHAP UPJONG_NM NRI_bdframe_NM  ... i15_CNT_SUM i7_roofSlope_cd_NM  \
# 0  10238.09        국유         철근콘크리트  ...           2   10 m 이하 또는 슬래브지붕
# 1   9225.41        판매         철근콘크리트  ...           5      11m 이상 20m 이하
# 2   3428.21        국유         철근콘크리트  ...           6   10 m 이하 또는 슬래브지붕
# 3   3768.22        병원         철근콘크리트  ...           5   10 m 이하 또는 슬래브지붕
# 4   3843.09        병원         철근콘크리트  ...           6   10 m 이하 또는 슬래브지붕
#
#   i9_roofMaterial_cd_NM   i8_roofShape_cd_NM  \
# ...

# %%
print(df.shape) #데이터의 규모
# Out:
# (36901, 25)

# %%
print(df.info) #데이터 현황 보기
# Out:
# <bound method DataFrame.info of        SEQ_NO  APLY_YEAR  F_BI_WIND  C  dpjgi_YEAR  dnum_csang_max  \
# 0           1       2020       1.16  0        1987               3
# 1           2       2020       1.37  0        2009               3
# 2           3       2020       1.18  0        2002               2
# 3           4       2020       1.23  0        1994               3
# 4           5       2020       1.30  0        1997               5
# ...       ...        ...        ... ..         ...             ...
# 36896   36897       2020       1.04  0        1994               1
# 36897   36898       2020       1.14  0        1995               1
# 36898   36899       2020       1.01  0        2000               3
# 36899   36900       2020       1.10  0        1997               3
# 36900   36901       2020       1.14  0        1998               5
#
#        dnum_cHA_max    YMJHAP UPJONG_NM NRI_bdframe_NM  ... i15_CNT_SUM  \
# ...

# %%
df[df['UPJONG_NM'].isnull()] #결측값이 포함된 행 찾기
# Out:
# Empty DataFrame
# Columns: [SEQ_NO, APLY_YEAR, F_BI_WIND, C, dpjgi_YEAR, dnum_csang_max, dnum_cHA_max, YMJHAP, UPJONG_NM, NRI_bdframe_NM, NRI_Wall_NM, NRI_rfframe_NM, FryingMaterial_NM, i6_CNT_SUM, i10_CNT_SUM, i15_CNT_SUM, i7_roofSlope_cd_NM, i9_roofMaterial_cd_NM, i8_roofShape_cd_NM, i11_wallCare_cd_NM, i12_door_cd_NM, i12_Door_Gather, i13_windowRate_cd_nm, i13_windowArea_cd_NM, i14_exposeArea_cd_nm]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.describe() #기술 통계값 보기
# Out:
#              SEQ_NO  APLY_YEAR     F_BI_WIND        C    dpjgi_YEAR  \
# count  36901.000000    36901.0  36901.000000  36901.0  36901.000000
# mean   18451.000000     2020.0      1.065457      0.0   2002.847999
# std    10652.545478        0.0      0.183249      0.0     10.859460
# min        1.000000     2020.0      0.000000      0.0   1800.000000
# 25%     9226.000000     2020.0      0.940000      0.0   1995.000000
# 50%    18451.000000     2020.0      1.070000      0.0   2004.000000
# 75%    27676.000000     2020.0      1.180000      0.0   2012.000000
# max    36901.000000     2020.0      1.990000      0.0   2020.000000
#
#        dnum_csang_max  dnum_cHA_max        YMJHAP    i6_CNT_SUM   i10_CNT_SUM  \
# count    36901.000000  36901.000000  3.690100e+04  36901.000000  36901.000000
# mean         5.004607      0.891493  2.875325e+04      4.202081      3.732419
# std          6.380970      1.449227  6.807903e+04      2.042596      1.487964
# ...

# %%
#시각화 도구 import
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#이상치 찾기
plt.figure(figsize=(16, 8))
sns.boxplot(x='NRI_bdframe_NM', y="dnum_cHA_max", data=df, palette="Paired")
